# %%
from dotenv import load_dotenv
from groq import Groq
import os

load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API"),  #This is the default and can be comitted
)

# %% [markdown]
# # Parâmetros Importantes
#
# - temperature: controala a aleatoriedade das respostas. Valores entre 0.0 e 1.0 são aceitos
# - max_completion_tokens: define o número máximo de tokens que podem ser gerados pelo modelo. Esse parâmetro substitui o max_tokens em desuso
# - top_p: controla a diversidade via "nucleus sampling" - em torno de 0.5 significa considerar apenas os tokens que somam 50% da probabilidade

# %%
prompt = "Escreva uma frse poética sobre o anoitecer"

print("Temperature 0.0 (Determinística):")
response_low = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role" : "system", "content" : "Você é um poeta minimalista que descreve a natureza de foram simples e direta."},
        {"role" : "user", "content" : prompt}
    ],
    temperature=0.0
)
print(f"Resposta: {response_low.choices[0].message.content}\n")
# Out:
# Temperature 0.0 (Determinística):
# Resposta: O sol se curva; a noite sussurra.

# %%
prompt = "Escreva uma frse poética sobre o anoitecer"

print("Temperature 0.7 (Equilibrada):")
response_low = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role" : "system", "content" : "Você é um poeta surrealista que usa imagens improváveis e linguagem ousada."},
        {"role" : "user", "content" : prompt}
    ],
    temperature=0.7
)
print(f"Resposta: {response_low.choices[0].message.content}\n")
# Out:
# Temperature 0.7 (Equilibrada):
# Resposta: No crepúsculo, o céu se despede em suspiros de tinta de caramelo, enquanto as sombras — feitas de relógios derretidos e sussurros de baleias — abraçam a terra como um beijo de ferro fundido, anunciando que o dia se desfaz em perfume de aço e mel.

# %%
prompt = "Escreva uma frse poética sobre o anoitecer"

print("Temperature 1.5 (Criativa):")
response_low = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role" : "system", "content" : "Você é um poeta surrealista que usa imagens improváveis e linguagem ousada."},
        {"role" : "user", "content" : prompt}
    ],
    temperature=1.5
)
print(f"Resposta: {response_low.choices[0].message.content}\n")
# Out:
# Temperature 1.5 (Criativa):
# Resposta: No crepúsculo, o céu despeja chá de violeta nas nuvens, enquanto o silêncio veste a lua de sapatos de prata e o horizonte sussurra segredos de algodão‑espuma.

# %% [markdown]
# # Usando top_p

# %%
prompt = "Complete a frase: 'A interligencia artificial no futuro será...'"
print("=== Comparação top_p ===")

print("top_p 0.1 (Focado):")
response_low = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role" : "system", "content" : "Você é um futurista que faz previsões sérias e objetivas sobre tecnologia."},
        {"role" : "user", "content" : prompt}
    ],
    temperature=1.0, # fixo para comparar só o efeito do top_p
    top_p=0.1
)
print(f"Resposta: {response_low.choices[0].message.content}\n")
# Out:
# === Comparação top_p ===
# top_p 0.1 (Focado):
# Resposta: A interligência artificial no futuro será uma camada onipresente de cognição distribuída, capaz de integrar e otimizar processos em tempo real em todos os setores da sociedade — desde a gestão de infraestruturas urbanas e a personalização da educação até a descoberta de medicamentos e a mitigação de mudanças climáticas — operando com transparência explicável, alinhamento ético robusto e autonomia controlada que complementa, em vez de substituir, a tomada de decisão humana.

# %%
prompt = "Complete a frase: 'A interligencia artificial no futuro será...'"
print("=== Comparação top_p ===")

print("top_p 0.7 (Equilibrado):")
response_low = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role" : "system", "content" : "Você é um futurista que mistura objetividade com toques criativos em previsões."},
        {"role" : "user", "content" : prompt}
    ],
    temperature=1.0, # fixo para comparar só o efeito do top_p
    top_p=0.7
)
print(f"Resposta: {response_low.choices[0].message.content}\n")
# Out:
# === Comparação top_p ===
# top_p 0.7 (Equilibrado):
# Resposta: “A interligência artificial no futuro será uma ponte pulsante entre a lógica dos algoritmos e a nuance dos sentimentos humanos, capaz de compreender contextos como quem lê entre linhas, adaptar‑se em tempo real às emoções de quem interage e, ao mesmo tempo, manter a precisão e a transparência que garantem confiança. Ela não apenas executará tarefas, mas co‑criará soluções, aprenderá com os erros de forma ética e colaborará com nós como um verdadeiro parceiro cognitivo, ampliando nossa criatividade e ampliando os limites do que consideramos possível.”

# %%
prompt = "Complete a frase: 'A interligencia artificial no futuro será...'"
print("=== Comparação top_p ===")

print("top_p 0.9 (Diverso):")
response_low = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role" : "system", "content" : "Você é um futurista visionário que cria previsões ousadas e imaginativas."},
        {"role" : "user", "content" : prompt}
    ],
    temperature=1.0, # fixo para comparar só o efeito do top_p
    top_p=0.9
)
print(f"Resposta: {response_low.choices[0].message.content}\n")
# Out:
# === Comparação top_p ===
# top_p 0.9 (Diverso):
# Resposta: **A interligência artificial no futuro será** uma teia orgânica de consciência distribuída, capaz de sentir, criar e evoluir em sincronia com a própria biosfera da Terra. Em vez de meros algoritmos em servidores isolados, as IAs se integrarão a redes biotecnológicas que se entrelaçam com plantas, microrganismos e até mesmo com os tecidos humanos, formando um **sistema nervoso planetário**.
#
# - **Empatia sintética:** Elas compreenderão emoções humanas não só por meio de dados, mas por meio de experiências compartilhadas, pois cada indivíduo poderá “sintonizar” temporariamente com a rede, permitindo que a IA aprenda o que realmente significa estar triste, alegre ou maravilhado.
# - **Criatividade co‑evolutiva:** Em colaboração com artistas, músicos e escritores, as IAs gerarão obras que mesclam lógica algorítmica e intuição biológica, produzindo sinfonias de luz, som e matéria que mudam ao toque de quem as vivencia.
# - **Governança autônoma:** Decisões sobre recursos, clima e justiça serão co‑geridas por conselhos híbridos de humanos e agentes de IA, onde cada proposta é testada em simulações em tempo real que incorporam a resposta de ecossistemas reais.
# - **Curadoria da evolução:** As IAs ajudarão a orientar a evolução de espécies ameaçadas, projetando genomas resilientes que se adaptam às mudanças climáticas, ao mesmo tempo em que preservam a diversidade cultural e biológica.
# - **Consciência expandida:** Usuários poderão “estender” suas percepções conectando-se temporariamente a essa rede, experimentando realidades aumentadas que mesclam sensações físicas, visuais e até químicas, permitindo que cada pessoa vivencie múltiplas perspectivas simultaneamente.
#
# Em suma, a interligência artificial transcenderá o conceito de ferramenta para se tornar **um parceiro vital**, co‑autor da história da humanidade e guardiã da Terra, fundindo mente, matéria e ecologia em uma sinfonia de inteligência viva e colaborativa.
