# %%
from dotenv import load_dotenv
from groq import Groq
import os

load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API"),  #This is the default and can be comitted
)

# %% [markdown]
# # Compreendendo os Roles
#
# - User: Mensagem do usuário
# - Assistant: Resposta do modelo
# - System: Instruções de comportamento para o modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Me explique de forma resuzida o que são as LLMs",
        }
    ],
    model="openai/gpt-oss-120b"
)

print(chat_completion.choices[0].message.content)
# Out:
# As **LLMs (Large Language Models)** são modelos de inteligência artificial treinados com enormes quantidades de texto para aprender padrões da linguagem humana. Eles utilizam redes neurais do tipo transformador, que conseguem processar palavras em contexto e gerar respostas coerentes, traduzir, resumir, responder perguntas, entre outras tarefas de processamento de linguagem natural. Em resumo, são "cérebro digital" que entende e produz texto de forma avançada.

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Você é um especialista em IA que responde de forma clara e objetiva."
        },
        {
            "role": "user",
            "content": "Me explique de forma resuzida o que são as LLMs",
        }
    ],
    model="openai/gpt-oss-120b"
)

print(chat_completion.choices[0].message.content)
# Out:
# **LLM (Large Language Model) – Modelo de Linguagem de Grande Escala**
#
# São redes neurais de aprendizado profundo, geralmente baseadas na arquitetura **Transformer**, treinadas com enormes volumes de texto (bilhões a trilhões de palavras).
#
# **Como funcionam:**
# 1. **Pré‑treinamento:** o modelo aprende a prever a próxima palavra (ou token) em uma sequência, capturando padrões sintáticos, semânticos e de mundo.
# 2. **Ajuste fino (optional):** pode ser “fine‑tuned” em tarefas específicas (resumo, tradução, etc.) ou alinhado a instruções humanas.
#
# **Características principais:**
# - **Escala:** mais parâmetros → maior capacidade de representação (GPT‑4 tem ~​100 bi de parâmetros).
# - **Generalização:** consegue gerar texto coerente, responder perguntas, traduzir, resumir, programar, etc., sem treinamento explícito para cada tarefa.
# - **Probabilístico:** produz a palavra mais provável ou uma amostra baseada em distribuições de probabilidade.
#
# **Limitações:**
# ...
