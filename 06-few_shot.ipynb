# %% [markdown]
# ### Técnicas Few Shot Prompting

# %% [markdown]
# - **Zero Shot**: Sem exemplos, apenas instruções
# - **One Shot**: Um exemplo para instruir o modelo
# - **Few Shot**: Múltiplos exemplos para melhor compreensão

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Zero Shot Prompting

# %%
system_prompt = """
Você é um chef renomado. 
Receba o nome de um ingrediente e sugira um prato sofisticado onde ele seja protagonista.
"""

user_prompt = "Abacate"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5
)

print("=== Zero Shot ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === Zero Shot ===
# Resposta: ### **Vieiras ao Ceviche de Lima Kaffir com Purê de Abacate e Pérolas de Yuzu**
# *Um prato onde o abacate assume o papel de textura aveludada e contraste refrescante, elevando o frescor do mar a um patamar de alta gastronomia.*
#
# ---
#
# #### **Conceito do prato**
# - **Protagonista:** Abacate – transformado em um purê aveludado que serve de “cama” para as vieiras.
# - **Contraponto cítrico:** Lima kaffir (folhas e suco) e yuzu, que trazem acidez perfumada.
# - **Textura:** Crocância delicada das pérolas de yuzu e um leve toque de sal marinho cristalizado.
# - **Harmonia:** Mar, fruta tropical e herbáceo, finalizados com um fio de azeite de oliva extra‑virgem envelhecido.
#
# ---
#
# #### **Ingredientes (para 4 porções)**
#
# | Ingrediente | Quantidade |
# |-------------|------------|
# | Vieiras frescas (sem concha) | 12 unidades (3 por pessoa) |
# | Abacate Hass maduro | 2 unidades médias |
# | Suco de lima kaffir | 30 ml |
# | Raspas de lima kaffir | 1 g (aprox. 1 folha ralada) |
# | Yuzu (suco) | 15 ml |
# | Gelatina de yuzu (para pérolas) | 2 g |
# | Água filtrada (para pérolas) | 200 ml |
# | Sal marinho cristalizado | 1 g (para finalizar) |
# | Azeite de oliva extra‑virgem (envelhecido 12 meses) | 10 ml |
# | Sal rosa do Himalaia | a gosto |
# | Pimenta branca moída na hora | a gosto |
# | Brotos de coentro (para decorar) | 8 g |
# | Micro‑brotos de rúcula | 4 g |
# | Flor de sal | pitada |
# | Gengibre fresco ralado | 0,5 g (opcional, para toque picante) |
#
# ---
#
# #### **Preparo passo a passo**
#
# 1. **Purê de Abacate**
#    1.1. Corte o abacate ao meio, retire o caroço e a polpa.
#    1.2. Passe a polpa por uma peneira fina para eliminar fibras.
#    1.3. Incorpore 15 ml de suco de lima kaffir, 1 g de raspas de lima kaffir, 2 g de sal rosa e 5 ml de azeite.
#    1.4. Bata levemente até obter uma textura sedosa (não aerada). Reserve em banho‑maria morno para manter a cremosidade.
#
# 2. **Ceviche de Vieiras**
#    2.1. Seque as vieiras com papel toalha. Tempere levemente com sal rosa e pimenta branca.
#    2.2. Em um bowl de vidro, misture 20 ml de suco de lima kaffir, 10 ml de suco de yuzu, 2 g de gengibre ralado e 2 ml de azeite.
#    2.3. Adicione as vieiras e deixe “marinar” por **30 segundos** – o tempo é curto para que a carne permaneça macia e translúcida.
#
# 3. **Pérolas de Yuzu (esferificação)**
#    3.1. Hidrate a gelatina de yuzu em 20 ml de água fria (5 min).
#    3.2. Leve ao fogo baixo, mexendo até dissolver completamente.
#    3.3. Misture com os 180 ml restantes de água filtrada gelada.
#    3.4. Use uma seringa ou pipeta para cair pequenas gotas (≈2 mm) em um banho de óleo frio (ou óleo de silicone a 4 °C). As gotas solidificam formando pérolas de 2 mm de diâmetro.
#    3.5. Coe delicadamente e reserve em água fria.
#
# 4. **Montagem**
#    4.1. Em um prato raso e branco, espalhe **um círculo de 20 ml** de purê de abacate, alisando com a parte de trás de uma colher de chá.
#    4.2. Sobre o purê, disponha as vieiras ceviche em forma de leque, deixando um pequeno espaço entre elas.
#    4.3. Regue com **5 ml** do líquido da marinada (coado) ao redor do purê, criando um “espelho” aromático.
#    4.4. Salpique as pérolas de yuzu ao redor e sobre as vieiras – elas estouram ao morder, liberando explosão cítrica.
#    4.5. Finalize com:
#    - 2 g de sal marinho cristalizado sobre cada vieira.
#    - Folhas de coentro e micro‑brotos de rúcula para cor e frescor.
#    - Um fio de azeite envelhecido ao redor do prato (circular, como um anel).
#
# 5. **Servir**
#    - Sirva imediatamente, ainda frio, para que a textura aveludada do purê e a delicadeza das vieiras se mantenham perfeitas.
#    - **Harmonização:** Espumante brut (Champagne ou Cava) ou um Sauvignon Blanc com notas de frutas tropicais e acidez vibrante.
#
# ---
#
# #### **Dicas de Chef**
#
# - **Abacate:** Escolha frutas que cedam levemente ao toque; se estiver muito maduro, o purê pode ficar aguado.
# - **Vieiras:** Se possível, compre as vieiras “dry‑aged” (secas) por 24 h em gelo; isso intensifica o sabor do mar.
# - **Esferificação:** A temperatura do óleo é crucial – se estiver muito quente, as pérolas se desfazem; se estiver fria demais, não formam a película externa.
# - **Apresentação:** Use pratos de porcelana branca ou preto fosco para realçar o verde do purê e o brilho das pérolas.
#
# ---
#
# **Resultado:**
# Um prato que celebra o abacate em sua forma mais elegante – como um leito cremoso que equilibra a delicadeza das vieiras, a acidez perfumada da lima kaffir e o “pop” inesperado das pérolas de yuzu. Cada garfada oferece textura, frescor e uma explosão de sabores que transportam o paladar para a costa tropical, porém com a sofisticação de uma cozinha de alto nível. Bon appétit!

# %% [markdown]
# ### One Shot Prompting

# %%
system_prompt = """
Você é um chef renomado. 
Receba o nome de um ingrediente e sugira um prato sofisticado onde ele seja protagonista.

Exemplo:
Ingrediente: Salmão
Sugestão -> Tartar de salmão fresco com molho cítrico e torradas de brioche
"""

user_prompt = "Cogumelos"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5
)

print("\n=== One Shot ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === One Shot ===
# Resposta: **Ingrediente:** Cogumelos
#
# **Sugestão de prato sofisticado:**
# **Ravioli de cogumelos silvestres ao molho de trufa negra, espuma de parmesão e crocante de alho-rosemary**
#
# **Descrição:**
# Delicados raviolis artesanais recheados com uma mistura cremosa de cogumelos porcini, shiitake, chanterelle e cogumelos de ostra, perfumados com um toque de vinho branco seco e tomilho fresco. O prato é finalizado com um luxuoso molho de trufa negra reduzido, sobre o qual repousa uma leve espuma de parmesão envelhecido, trazendo leveza e profundidade de sabor. Para contraste de textura, adicionamos finas lascas de alho crocante temperado com alecrim (rosemary) e um fio de azeite extra-virgem frio.
#
# **Montagem:**
# 1. Disponha três raviolis no centro do prato, formando um pequeno triângulo.
# 2. Regue delicadamente com o molho de trufa, permitindo que escorra levemente pelas laterais.
# 3. Aplique a espuma de parmesão sobre o topo, usando um sifão ou colher de chá para criar um leito aerado.
# 4. Salpique o crocante de alho‑rosemary ao redor e finalize com algumas folhas de micro‑hortelã para frescor visual.
#
# **Harmonização:**
# Vinho branco seco e aromático, como um Chardonnay da Borgonha ou um Sauvignon Blanc do Vale do Loire, que realça a terra dos cogumelos sem sobrepor a sutileza da trufa.

# %% [markdown]
# ### Few Shot Prompting

# %%
system_prompt = """
Você é um chef renomado. 
Receba o nome de um ingrediente e sugira um prato sofisticado onde ele seja protagonista.

<exemplos>
Ingrediente: Tomate
Sugestão <-> Carpaccio de tomate com azeite trufado e manjericão fresco

Ingrediente: Chocolate
Sugestão <-> Soufflé de chocolate meio amargo com calda de frutas vermelhas

Ingrediente: Batata
Sugestão <-> Nhoque artesanal de batata ao molho de manteiga e sálvia
</exemplos>
"""

user_prompt = "Camarão"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.4
)

print("\n=== Few Shot ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === Few Shot ===
# Resposta: Ingrediente: Camarão
# Sugestão <-> Camarões ao vapor em espuma de champagne com limão siciliano, acompanhados de risoto de açafrão e crocante de pistache torrado.

# %% [markdown]
# ### Few Shot Criativo

# %%
system_prompt = """
Você é um chef criativo que mistura ingredientes improváveis em pratos sofisticados.

Exemplos:
Combinação: Manga + Pimenta
Prato -> Ceviche de manga apimentado com chips de batata doce

Combinação: Café + Laranja
Prato -> Entrecôte ao molho de café e raspas de laranja

Combinação: Queijo azul + Melancia
Prato -> Salada refrescante de melancia com queijo azul e nozes
"""

user_prompt = "Combinação: Morango + Manjericão"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.7
)

print("\n=== Few Shot Criativo ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === Few Shot Criativo ===
# Resposta: **Prato:** *Mousse de Morango com Espuma de Manjericão e Crocante de Pistache*
#
# **Descrição:**
# Um contraste delicado entre a doçura vibrante do morango e o frescor herbáceo do manjericão, tudo em camadas texturizadas. A mousse aveludada de morango, levemente acentuada com um toque de vinagre balsâmico branco, recebe por cima uma espuma leve de manjericão que explode na boca, enquanto um crocante de pistache torrado traz o final crocante que equilibra o prato. Servido em taças de cristal, é perfeito como entrada sofisticada ou sobremesa refinada.
#
# ---
#
# ### Ingredientes (para 4 porções)
#
# | Ingrediente | Quantidade |
# |-------------|------------|
# | Morangos frescos, lavados e sem folhas | 300 g |
# | Açúcar de confeiteiro | 60 g |
# | Creme de leite fresco (30 % de gordura) | 150 ml |
# | Gelatina sem sabor | 2 folhas |
# | Vinagre balsâmico branco | 1 cálice (≈ 15 ml) |
# | Folhas de manjericão fresco | 20 g |
# | Creme de leite fresco (para a espuma) | 80 ml |
# | Leite integral | 40 ml |
# | Sal marinho | Pitada |
# | Pistaches sem casca, torrados e picados | 30 g |
# | Açúcar mascavo | 1 cálice (≈ 15 g) |
# | Água | 1 cálice (para o caramelo) |
# | Folhas de manjericão para decorar | 4 unidades |
#
# ### Modo de preparo
#
# 1. **Mousse de morango**
#    1.1. Hidrate as folhas de gelatina em água fria por 5 min.
#    1.2. No liquidificador, bata os morangos com o açúcar de confeiteiro até obter um purê liso.
#    1.3. Aqueça 2 cálices de água, esprema a gelatina hidratada e dissolva‑a completamente. Incorpore ao purê de morango junto ao vinagre balsâmico.
#    1.4. Bata o creme de leite até ponto de chantilly firme e, delicadamente, incorpore ao purê de morango em movimentos de baixo para cima.
#    1.5. Distribua a mousse em taças de cristal e leve à geladeira por, no mínimo, 2 h.
#
# 2. **Espuma de manjericão**
#    2.1. Blanchar as folhas de manjericão em água fervente por 10 s, resfriar em gelo e escorrer bem.
#    2.2. No liquidificador, bata o manjericão com o creme de leite, o leite e uma pitada de sal até ficar homogêneo. Coe em pano fino para eliminar resíduos.
#    2.3. Transferir a mistura para um sifão de chantilly, carregar com duas cartuchos de N₂O e deixar na geladeira por 30 min.
#
# 3. **Crocante de pistache**
#    3.1. Em uma panela pequena, derreta o açúcar mascavo com a água até obter um caramelo dourado.
#    3.2. Adicione os pistaches picados, mexa rapidamente e despeje sobre uma folha de papel manteiga. Deixe esfriar e quebre em pedaços pequenos.
#
# 4 Montagem
#    - Sobre a mousse firme, aplique 1 cálice de espuma de manjericão usando o sifão, criando um véu leve.
#    - Salpique o crocante de pistache por cima.
#    - Decore com uma folha inteira de manjericão fresca, levemente dobrada.
#
# 5. **Servir**
#    - Sirva imediatamente, para que a espuma mantenha sua textura aerada e o crocante permaneça quebradiço.
#
# **Dica do chef:**
# Para intensificar o frescor, adicione ao purê de morango um toque de suco de limão siciliano (½ cálice). O cítrico realça a doçura natural do fruto e cria um contraponto ainda mais elegante ao aroma do manjericão. Bon appétit!
